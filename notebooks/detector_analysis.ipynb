# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO("C:/CliniScan/runs/detect/train/weights/best.pt")

print("YOLO model loaded successfully")
# Out:
# YOLO model loaded successfully

# %%
metrics = model.val(data="C:/CliniScan/data/dataset.yaml")

print(metrics)
# Out:
# Ultralytics 8.4.13  Python-3.12.8 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 1435.2391.5 MB/s, size: 192.3 KB)
# val: Scanning C:\CliniScan\data\labels\val.cache... 436 images, 1064 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500  0.0s
# val: C:\CliniScan\data\images\val\001d127bad87592efe45a5c7678f8b8d.png: 1 duplicate labels removed
# val: C:\CliniScan\data\images\val\0046f681f078851293c4e710c4466058.png: 1 duplicate labels removed
# val: C:\CliniScan\data\images\val\013893a5fa90241c65c3efcdbdd2cec1.png: 3 duplicate labels removed
# val: C:\CliniScan\data\images\val\0162dad8330007f8f0daf43bcf4033f1.png: 1 duplicate labels removed
# val: C:\CliniScan\data\images\val\018a2fe44c3451281ec338c27ecc9c53.png: 4 duplicate labels removed
# val: C:\CliniScan\data\images\val\02d9d0c89022adc381c23e72add7c389.png: 1 duplicate labels removed
# ...

# %%
results = model.predict(
    source="C:/CliniScan/data/images/test",
    conf=0.25,
    save=True
)

print("Predictions saved to runs/detect/predict/")
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1500 C:\CliniScan\data\images\test\0005e8e3701dfb1dd93d53e2ff537b6e.png: 704x704 1 abnormal, 18.2ms
# image 2/1500 C:\CliniScan\data\images\test\0021df30f3fddef551eb3df4354b1d06.png: 704x704 (no detections), 18.1ms
# image 3/1500 C:\CliniScan\data\images\test\003cfe5ce5c0ec5163138eb3b740e328.png: 704x704 (no detections), 18.1ms
# ...

# %%
results = model.predict(
    source="C:/CliniScan/data/images/test",
    conf=0.35,
    save=True,
    project="runs/detect",
    name="predict_conf035"
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1500 C:\CliniScan\data\images\test\0005e8e3701dfb1dd93d53e2ff537b6e.png: 704x704 (no detections), 18.4ms
# image 2/1500 C:\CliniScan\data\images\test\0021df30f3fddef551eb3df4354b1d06.png: 704x704 (no detections), 18.3ms
# image 3/1500 C:\CliniScan\data\images\test\003cfe5ce5c0ec5163138eb3b740e328.png: 704x704 (no detections), 18.2ms
# ...

# %%
results = model.predict(
    source="C:/CliniScan/data/images/test",
    conf=0.35,
    save=True,
    project="runs/detect",
    name="predict_conf035"
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1500 C:\CliniScan\data\images\test\0005e8e3701dfb1dd93d53e2ff537b6e.png: 704x704 (no detections), 18.1ms
# image 2/1500 C:\CliniScan\data\images\test\0021df30f3fddef551eb3df4354b1d06.png: 704x704 (no detections), 18.4ms
# image 3/1500 C:\CliniScan\data\images\test\003cfe5ce5c0ec5163138eb3b740e328.png: 704x704 (no detections), 18.2ms
# ...

# %%
results = model.predict(
    source="C:/CliniScan/data/images/test",
    conf=0.45,
    save=True,
    project="C:/CliniScan/runs/detect",
    name="predict_conf045"
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1500 C:\CliniScan\data\images\test\0005e8e3701dfb1dd93d53e2ff537b6e.png: 704x704 (no detections), 18.2ms
# image 2/1500 C:\CliniScan\data\images\test\0021df30f3fddef551eb3df4354b1d06.png: 704x704 (no detections), 18.4ms
# image 3/1500 C:\CliniScan\data\images\test\003cfe5ce5c0ec5163138eb3b740e328.png: 704x704 (no detections), 18.2ms
# ...

# %%
plt.imshow(cv2.cvtColor(cv2.imread("C:/CliniScan/runs/detect/predict/0ad8d7f0f8a9bc784c8bb38e50a63beb.jpg"), cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %%
results = model.predict(
    source="C:/CliniScan/data/images/test",
    conf=0.25,
    save=True
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1500 C:\CliniScan\data\images\test\0005e8e3701dfb1dd93d53e2ff537b6e.png: 704x704 1 abnormal, 268.2ms
# image 2/1500 C:\CliniScan\data\images\test\0021df30f3fddef551eb3df4354b1d06.png: 704x704 (no detections), 21.9ms
# image 3/1500 C:\CliniScan\data\images\test\003cfe5ce5c0ec5163138eb3b740e328.png: 704x704 (no detections), 21.9ms
# ...

# %%
metrics = model.val(
    data="C:/CliniScan/data/dataset.yaml"
)

print("Precision:", metrics.box.mp)
print("Recall:", metrics.box.mr)
print("mAP50:", metrics.box.map50)
print("mAP50-95:", metrics.box.map)
# Out:
# Ultralytics 8.4.13  Python-3.12.8 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# val: Fast image access  (ping: 0.20.1 ms, read: 24.63.8 MB/s, size: 188.4 KB)
# val: Scanning C:\CliniScan\data\labels\val.cache... 436 images, 1064 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500  0.0s
# val: C:\CliniScan\data\images\val\001d127bad87592efe45a5c7678f8b8d.png: 1 duplicate labels removed
# val: C:\CliniScan\data\images\val\0046f681f078851293c4e710c4466058.png: 1 duplicate labels removed
# val: C:\CliniScan\data\images\val\013893a5fa90241c65c3efcdbdd2cec1.png: 3 duplicate labels removed
# val: C:\CliniScan\data\images\val\0162dad8330007f8f0daf43bcf4033f1.png: 1 duplicate labels removed
# val: C:\CliniScan\data\images\val\018a2fe44c3451281ec338c27ecc9c53.png: 4 duplicate labels removed
# val: C:\CliniScan\data\images\val\02d9d0c89022adc381c23e72add7c389.png: 1 duplicate labels removed
# ...

# %%
results = model.predict(
    source="C:/CliniScan/data/images/test",
    conf=0.25,
    save=True
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1500 C:\CliniScan\data\images\test\0005e8e3701dfb1dd93d53e2ff537b6e.png: 704x704 1 abnormal, 242.9ms
# image 2/1500 C:\CliniScan\data\images\test\0021df30f3fddef551eb3df4354b1d06.png: 704x704 (no detections), 22.0ms
# image 3/1500 C:\CliniScan\data\images\test\003cfe5ce5c0ec5163138eb3b740e328.png: 704x704 (no detections), 21.9ms
# ...
